# %%
import random
import secrets
from tqdm import tqdm
import numpy as np
import time
import math

import networkx as nx
import matplotlib.pyplot as plt
import seaborn as sns

# %%
'''
Project 3

Repetir o Projeto 1 respectivamente ao modelo Barbási-Albert.

'''

def random_graph(N_random=100):
    '''
    Defines a graph with N nodes and random connections:
    '''
    G = nx.Graph()
    for node in range(N+1):
        G.add_node(node)
        
    nodes = list(G.nodes())    
    for node in nodes:
        random_node = secrets.choice(nodes)
        G.add_edge(node, random_node)           
    
    return G

def ba_graph(N, m=3):
    
    G = random_graph()
    
    dict_degree = dict(G.degree())
    list_k_nodes = []
    for k_value, k_freq in dict_degree.items():
        for freq in range(k_freq):
            list_k_nodes.append(k)
            
    for node in range(len(G), N-1):
        for conn in range(m):
            random_node = secrets.choice(list_k_nodes)
            G.add_edge(node, random_node)

    plt.title("Barabási-Albert Network generated with {} nodes.".format(N))
    pos = nx.spring_layout(G)
    fig_net = nx.draw(G, pos, node_color='w', node_size=1, with_labels=False)
    plt.show(fig_net)
    
    return G
    
N = 1000
G = ba_graph(N)

# %%
len(G)
# Out:
# 1001

# %%
"""
pca: ER, voronoi, circulo, waxman, ws-p pequeno, ws pmedio, ws palto, ba
500 nos, grau medio ~ 5

os que darão caminho longo: geográfico e ws p pequeno



"""
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-c984d8e69080> in <module>
# ----> 1 PCA
#
# NameError: name 'PCA' is not defined
