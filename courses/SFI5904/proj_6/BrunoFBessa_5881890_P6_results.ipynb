# %% [markdown]
# ## SFI5904 - Complex Networks
#
# Project 6: Dynamics of difusion and probabilistic automata<br>
# First Semester of 2021
#
# Professor: Luciano da Fontoura Costa (luciano@ifsc.usp.br) <br>
#
# Student: Bruno F. Bessa (num. 5881890, bruno.fernandes.oliveira@usp.br) <br>
# Universidade de São Paulo, São Carlos, Brazil.

# %% [markdown]
# Implement all the automata analyzed in CDT-22 [1], reproducnf the figures of this work.

# %% [markdown]
# ## Results

# %% [markdown]
# The following figures represent three alternatives of representation of a deterministic automaton with fixed transitions given by the sequence:
# (1, 0, 1, 1)

# %%
display.Image("images/deterministic_automaton_representations.png")

# %% [markdown]
# Here ve have three samples for each probabilistic pattern given in CDT-22 figure 6: a (left), b (middle), c (right).

# %%
display.Image("images/probabilistic_automata_patterns.png")

# %% [markdown]
# The square wave plot below represents the probabilistic sequential automaton with more than two possible states given in CDT-22 figure 6 d.

# %%
display.Image("images/spa_d.png")

# %% [markdown]
# The square wave plot resembles a barcode plot for the binary probabilistic sequential automaton of CDT22 figure 6 e:

# %%
display.Image("images/spa_e.png")

# %% [markdown]
# Generation of visual patterns with horizontal and vertical lines following the binary patterns, as seen in CDT-22 figure 11:

# %%
display.Image("images/hv_lines.png")

# %% [markdown]
# Visual pattern of circles centered at the intersection of vertical and horizontal lines created by the same binary automaton (CDT-22 figure 12):

# %%
display.Image("images/circles_centered.png")

# %% [markdown]
# Rensities of relative number of 1s obtained by binary probabilistc automata (a, b, c), as seen in CDT-22 figure 13.

# %%
display.Image("images/abc_patterns_distplot.png")

# %% [markdown]
# Rensities of relative number of 1s obtained by binary probabilistc automata with overlaping probabilities, as seen in CDT-22 figure 14.

# %%
display.Image("images/5050_patterns_distplot.png")

# %% [markdown]
# ## Conclusions
#
# The generation of patterns with probabilistic automata can be useful to produce dynamics in complex networks. It is important to be able to reproduce such patterns in order to generate synthetic difusion fenomena.

# %% [markdown]
# ## References
#
# [1] L. da F. Costa. Where Do Patterns To Be Recognized Come From?. Researchgate, March 2020.
