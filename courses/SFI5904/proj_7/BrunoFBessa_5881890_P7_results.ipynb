# %% [markdown]
# ## SFI5904 - Complex Networks
#
# Project 7: Relationship between topolody and dynamics in complex netwoks<br>
# First Semester of 2021
#
# Professor: Luciano da Fontoura Costa (luciano@ifsc.usp.br) <br>
#
# Student: Bruno F. Bessa (num. 5881890, bruno.fernandes.oliveira@usp.br) <br>
# Universidade de São Paulo, São Carlos, Brazil.

# %% [markdown]
# A: Obtain scatterplots and respective Pearson correation coefficients between the degree and the activation rate for each node of at least 300 nodes with average degree between 5 and 7. Use one network for each one of the models ER, BA, WS (with 3 probabilities of reconnection) as well as the three geometric models seen during the course.
#
# B: Make the networks used in (A) more and more directed, removing individual connections from them and check the effect on the correlations.

# %% [markdown]
# ## Results (A)
#
# For this experiment the following synthetic networks were used (all with N=300 nodes and tuned so that their average degree lied between 5 and 7):
#
# ER = Erdos-Renyi (prob=0.02)
#
# BA = Barabási-Albert (m=4, plot=False)
#
# VO = Voronoi
#
# RA = Spatial with Radius (radius=0.079)
#
# WX = Waxman (alpha=0.048
#
# WS_1 = Watts-Strogatz (prob=0.1)
#
# WS_2 = Watts-Strogatz (prob=0.2)
#
# WS_3 = Watts-Strogatz (prob=1.0)
#
# We performes random walks to calculate the activation rate of the undirected networks.

# %%
display.Image("images/results_a.png")

# %% [markdown]
# ## Results (B)
#
# In order to reproduce the effect of the steering coefficient as function of the topology, we created a function that loops over the edges of an undirected graph and reconnects it with direction following a probability.

# %%
display.Image("images/reconnect_directed.png")

# %% [markdown]
# The results are listed in the figures below:

# %%
display.Image("images/er_evolution.png")

# %%
display.Image("images/ba_evolution.png")

# %%
display.Image("images/vo_evolution.png")

# %%
display.Image("images/ra_evolution.png")

# %%
display.Image("images/wx_evolution.png")

# %%
display.Image("images/ws_1_evolution.png")

# %%
display.Image("images/ws_2_evolution.png")

# %%
display.Image("images/ws_3_evolution.png")

# %% [markdown]
# ## Conclusion
#
# It is clear that the activation rate is higly correlated with the degree of a network for undirected graphs.
#
# As the reciprocity of the network decreases the correlation becomes weaker.

# %% [markdown]
# ## References
#
# [1] Sousa, J. P., Comin, C. H., Costa, L. F., Topology and Dynamics in Complex Networks: The Role of Edge Reciprocity, arXiv:1711.08838, Nov. 2017.
