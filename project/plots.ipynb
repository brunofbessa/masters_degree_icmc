# %%
import matplotlib.pyplot as plt

# %matplotlib inline
import numpy as np
import pandas as pd

import seaborn as sns

sns.set_style("ticks")

# %%
raw_df = pd.read_csv(r'./csv_objects/training/model_20ng_20ng_tpbg_docf_None_nl_2_pd_0.0_act_ce_ver_1_hid_100_layers_2_pdrop_0.0.csv', delimiter=";", decimal=",", index_col=False)


df_loss_train = raw_df[['epoch', 'loss_train']]
df_loss_train['dataset'] = 'training'
df_loss_train.columns=['epoch', 'loss', 'dataset']

df_loss_test = raw_df[['epoch', 'loss_test']]
df_loss_test['dataset'] = 'validation'
df_loss_test.columns=['epoch', 'loss', 'dataset']


df_result = pd.concat([df_loss_train, df_loss_test],)
# Out:
# /var/folders/2h/88ywypjd741fxv633b03fmd00000gn/T/ipykernel_2558/974095560.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_loss_train['dataset'] = 'training'
# /var/folders/2h/88ywypjd741fxv633b03fmd00000gn/T/ipykernel_2558/974095560.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_loss_test['dataset'] = 'validation'

# %%
g = sns.catplot(x="epoch", y="loss", hue='dataset', data=df_result)

# %%
res = sns.scatterplot(x="epoch", y="loss_train", data=df_loss_train)
plt.show()

# %%
res = sns.scatterplot(x="epoch", y="loss_train", data=csv)
plt.show()
